# %%
import numpy as np 
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd

# %%
f = "ml2023_projectmbf-main/data_labeled_fixed.csv"

# %%
f = "../../ml2023/data_labeled.csv"

# %%
df = pd.read_csv(f, header=0)

# %%
df.head()
# Out:
#    Acin1  Actb  Agap1  Ahi1  Akap11  Akap9  Aldoa  Aldoc  Ankrd12  Anp32a  \
# 0      3     0      0     1       2      0      1      0        3       2
# 1      0     1      0     0       0      0      3      0        0       4
# 2      0     0      0     0       0      0      2      1        0       0
# 3      0     1      0     4       0      0      1      0        0       1
# 4      0     1      0     1       0      0      7      1        2       4
#
#    ...  mt-Co1  mt-Cytb  mt-Nd1  mt-Nd2  mt-Nd4  mt-Nd5  mt-Rnr1  mt-Rnr2  \
# 0  ...       0       12       3       5       5       4        2       25
# 1  ...       1        5       1       0       2       1        0       16
# 2  ...       0       12       5       3      10       4        1       14
# 3  ...       0        8       1       3       3       1        0        7
# 4  ...       0       17       7       3       0       4        0        3
#
#    CELLTYPE             CLASS
# 0       BC6   Cone Bipolar ON
# 1      BC3B  Cone Bipolar OFF
# 2       BC6   Cone Bipolar ON
# 3      BC3A  Cone Bipolar OFF
# 4       BC7   Cone Bipolar ON
#
# [5 rows x 454 columns]

# %%
df.shape
# Out:
# (3724, 454)

# %% [markdown]
# # Principal Component Analysis

# %%
exp = df.drop(["CLASS", "CELLTYPE"], axis = 1)
genes = exp.columns

# %%
scaler = StandardScaler().fit(exp)
exp = scaler.transform(exp)

# %%
ncomp =  451
pca = PCA(n_components=ncomp)

# %%
comp = pca.fit_transform(exp)
score = pd.DataFrame(comp, columns=["".join(["PC", str(x)]) for x in range(1,ncomp+1)])
score = pd.concat([score, df["CLASS"]], axis = 1)

# %%
loadings = pd.DataFrame(np.transpose(pca.components_), columns = ["".join(["PC", str(x)]) for x in range(1,ncomp+1)])
labels = pd.DataFrame(genes, columns=["gene"])
loadings = pd.concat([loadings, labels], axis =1)

# %%
loadings[["PC1"]].idxmax()
# Out:
# PC1    138
# dtype: int64

# %%
loadings.PC2.idxmax()
# Out:
# 146

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as Colors

# %%
pca.explained_variance_ratio_.sum()
# Out:
# 0.9996460209127821

# %%
varexp = pca.explained_variance_ratio_[:51]*100

# %%
fig, axes = plt.subplots(1,2, figsize = (10, 5), sharex=True)
axes[0].plot(varexp)
axes[0].set_xlabel("component")
axes[0].set_ylabel("variance explained (%)")
axes[0].grid()

axes[1].plot(varexp.cumsum(), "r")
axes[1].set_xlabel("component")
axes[1].set_ylabel("variance explained cummulative (%)")
axes[1].grid()
plt.savefig("variance_explained_PCA.png", dpi = 350)

# %%
def biplot(score, loadings,n, sf = 0.5):
    xs = score.iloc[:,0]
    ys = score.iloc[:,1]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())
    
    fig, axes = plt.subplots(figsize = (7, 7))
    sns.scatterplot(ax=axes, x= score.PC1 * scalex, y=score.PC2*scaley, hue = df["CLASS"], alpha =0.6)
    abs_loadings = abs(loadings[["PC1", "PC2"]])

    arrows = np.concatenate([abs_loadings.PC1.nlargest(n).index.values, abs_loadings.PC2.nlargest(n).index.values])
    
    for arrow in arrows:
        x, y, label = loadings.iloc[arrow, :]
        if x**2 > 0.1 or y**2 > 0.001:
            x, y = x * sf, y * sf
            plt.arrow(0, 0,  x, y, color = 'r',alpha = 0.5)
            plt.text(x * 1.15, y * 1.15, label, va = "center", ha = "center", size = 10)

    plt.xlabel("PC1")
    plt.ylabel("PC2")
    plt.grid()

# %%
biplot(score, loadings[["PC1", "PC2", "gene"]],3, 2)
plt.xlabel("PC1 (3.43%)")
plt.ylabel("PC2 (2.77%)")
plt.savefig("pca_w_vector.png", dpi = 350)

# %%
abs_loadings = abs(loadings[["PC1", "PC2"]])

# %%
pc1 = loadings.iloc[abs_loadings.PC2.nlargest(15).index]
pc2 = loadings.iloc[abs_loadings.PC1.nlargest(15).index]

# %%
pc1.to_csv("nlargest_pc1_genes.csv", index=False,float_format = "%.3f")
pc2.to_csv("nlargest_pc2_genes.csv", index=False,float_format = "%.3f")

# %% [markdown]
# # k-means

# %%
from sklearn.cluster import KMeans

# %%
def km_cluster(data, nk = range(1, 3)):

    res = []
    for k in nk:
        km = KMeans(n_clusters=k)
        fitted = km.fit(data)
        res.append(fitted.inertia_)
    
    res = np.array(res)
    X = x = np.arange(1,len(nk)+1, step = 1)
    
    fig, axes = plt.subplots(1,1, figsize = (5,5))
    sns.lineplot(x = X, y = res, ax=axes, color = "black")
    sns.scatterplot(x = X, y=res, ax=axes, color = "r")
    plt.xlabel("k")
    plt.ylabel("Inertia")
    plt.xticks(X)
    plt.grid()

# %%
km_cluster(exp, nk = range(1, 10))
plt.axvline(6, linestyle="--", color = "r")
plt.savefig("kmeans_elbowplot.png", dpi = 350)

# %%
km = KMeans(n_clusters=6)
fitted = km.fit(exp)

# %%
cl_score = pd.concat([score, pd.Series(fitted.labels_, name = "Cluster")], axis = 1)

# %%
cl_score
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     1.809979 -1.176693  1.154901  4.263111  7.212358 -7.043940 -4.032425
# 1    -0.456681  8.354357  5.610428 -0.569967 -2.068058 -3.017672 -0.527557
# 2     8.067992  2.022647 -2.787995  0.046320  0.359902 -2.611424 -1.130072
# 3     1.498081  4.814254 -0.479978  4.010789 -1.461298  2.262081 -4.222279
# 4     7.122736  2.570324 -0.035781 -4.959219 -3.678160  2.893631  0.836860
# ...        ...       ...       ...       ...       ...       ...       ...
# 3719 -3.790940 -3.905104 -1.867869 -0.721631 -0.326656 -0.966100  0.206926
# 3720 -4.214774 -3.078015 -1.548137 -3.474504  1.035602  0.329911  0.485678
# 3721 -3.638886 -3.846498 -0.472737 -2.304239  0.378499 -0.288065  0.367620
# 3722 -3.992286 -1.789471 -3.045839  0.784472  0.895811  1.485962  3.136485
# 3723 -5.579494 -2.928328 -2.464638  0.944167  1.528646  1.675821  2.331637
#
#            PC8       PC9      PC10  ...     PC444     PC445     PC446  \
# 0     0.588446  1.185198  0.196492  ... -0.756820 -0.148072  0.545476
# 1     3.059830  1.859878 -0.692429  ...  0.705780  0.689896  0.164239
# 2     0.455603  5.897153  0.692622  ...  0.800872  0.298388 -0.356871
# 3    -1.128459 -0.334426  2.592167  ... -0.005441 -0.451706  2.163237
# 4     1.382901  1.084666 -0.825960  ...  0.509953 -0.028193 -0.084550
# ...        ...       ...       ...  ...       ...       ...       ...
# 3719 -0.377365 -1.264894  1.786192  ... -0.192142 -0.157221 -0.036284
# 3720  0.005188 -1.514862  0.690796  ... -0.090656 -0.234996  0.172650
# 3721 -0.014494 -2.178394  1.145658  ... -0.143543  0.417733  0.041296
# 3722  1.100327 -2.489424 -0.063299  ...  0.033519 -0.106150  0.181977
# 3723  0.715097 -1.539123 -0.009518  ...  0.481251 -0.017454 -0.050793
#
#          PC447     PC448     PC449     PC450     PC451             CLASS  \
# 0     0.808120  1.095832  0.007277 -0.270825 -0.506775   Cone Bipolar ON
# 1     0.136531 -0.073337 -0.017322 -0.142111  0.201782  Cone Bipolar OFF
# 2    -0.042493  0.086346  0.219944 -0.038898 -0.433191   Cone Bipolar ON
# 3    -0.835188  1.053946  0.120604 -0.777496  0.461942  Cone Bipolar OFF
# 4     0.066186 -0.075901  0.543954  0.343663  0.480510   Cone Bipolar ON
# ...        ...       ...       ...       ...       ...               ...
# 3719 -0.461925  0.282380  0.242280  0.189907 -0.399306   Cone Bipolar ON
# 3720 -0.434981 -0.726404  0.394710 -0.657102 -0.012436   Cone Bipolar ON
# 3721 -0.182862 -0.413178  0.271514 -0.220342  0.335616   Cone Bipolar ON
# 3722  0.214038 -0.366594 -0.098558  0.739317  0.240095  Cone Bipolar OFF
# 3723  0.712984  0.286031 -0.285298 -0.056992  0.455717  Cone Bipolar OFF
#
#       Cluster
# 0           2
# 1           0
# 2           2
# 3           4
# 4           2
# ...       ...
# 3719        3
# 3720        3
# 3721        3
# 3722        3
# 3723        3
#
# [3724 rows x 453 columns]

# %%
def is_in(x, l):
    if x in l:
        x = True
    else: 
        x = False
    return x

# %%
fig, axes = plt.subplots(2, 2, figsize=(9,6), sharex = True, sharey = True)
place = pd.DataFrame(np.matrix("0 0; 0 1;1 0; 1 1"))
colormap = dict(zip( range(0,6), sns.color_palette(as_cmap = True)[:-3]))

for i, (k, sub) in enumerate(cl_score.groupby("CLASS")):
    ii, j = place.iloc[i,:]
    
    sns.scatterplot(data=sub, x="PC1", y="PC2", hue="Cluster", palette=colormap, ax=axes[ii, j], alpha =1)
    axes[ii,j].set_xlabel("")
    axes[ii,j].set_ylabel("")
    axes[ii,j].set_title(k, size = 10)
    axes[ii,j].get_legend().remove()
    axes[ii,j].grid()
    
fig.add_subplot(111, frameon=False)
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel("PC1 (3.43%)")
plt.ylabel("PC2 (2.77%)")

handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=label) for label, color in colormap.items()]
fig.legend(handles=handles, loc="right", ncol=1)
plt.savefig("kmeans_6_inPCA.png", dpi = 350, bbox_inches="tight")

# %%
colormap
# Out:
# {0: '#1f77b4',
#  1: '#ff7f0e',
#  2: '#2ca02c',
#  3: '#d62728',
#  4: '#9467bd',
#  5: '#8c564b'}

# %%
colormap
# Out:
# {0: '#1f77b4',
#  1: '#ff7f0e',
#  2: '#2ca02c',
#  3: '#d62728',
#  4: '#9467bd',
#  5: '#8c564b'}

# %%
colormap
# Out:
# {0: (0.8941176470588236, 0.10196078431372549, 0.10980392156862745),
#  1: (0.21568627450980393, 0.49411764705882355, 0.7215686274509804),
#  2: (0.30196078431372547, 0.6862745098039216, 0.2901960784313726),
#  3: (0.596078431372549, 0.3058823529411765, 0.6392156862745098),
#  4: (1.0, 0.4980392156862745, 0.0),
#  5: (1.0, 1.0, 0.2)}

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.color_palette(as_cmap=True)
# Out:
# ['#1f77b4',
#  '#ff7f0e',
#  '#2ca02c',
#  '#d62728',
#  '#9467bd',
#  '#8c564b',
#  '#e377c2',
#  '#7f7f7f',
#  '#bcbd22',
#  '#17becf']
